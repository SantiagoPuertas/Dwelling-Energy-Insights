# %%
# %reset
# from __future__ import division
#Importing packages for analyzing useses
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Import the data and making a dataframe out of it



file_name = '../Data/dataGM_excel2.xlsx'
productionDF = pd.read_excel(file_name, sheet_name='Productie')
consumptionDF = pd.read_excel(file_name, sheet_name='Consumptie')
productionDF.head()
consumptionDF.head()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
#              ID-nummer             H01             H02             H03  \
# 0              concept               E               E              WP
# 1            PV-aantal              17              14               9
# 2             personen               4               2               4
# 3       Datum-tijd tot  Consumptie kWh  Consumptie kWh  Consumptie kWh
# 4  2017-07-11 00:15:00           0.038           0.039           0.044
#
#               H04             H05             H06             H07  \
# 0              WP              WP               E               E
# 1              11              12              14              13
# 2               1               4               4               2
# 3  Consumptie kWh  Consumptie kWh  Consumptie kWh  Consumptie kWh
# 4           0.024             NaN           0.039           0.025
#
#               H08             H09  ...             H24             H25  \
# ...

# %%
df_prod_1 = productionDF.iloc[4:100,0:2]
df_cons_1 = consumptionDF.iloc[4:100,1:2]

df_house_1 = df_prod_1
df_house_1.columns = ['date', 'prod']
df_house_1['cons'] = df_cons_1
df_house_1.set_index('date', inplace=True)

df_house_1.head()
# Out:
#                     prod   cons
# date
# 2017-07-11 00:15:00    0  0.038
# 2017-07-11 00:30:00    0  0.018
# 2017-07-11 00:45:00    0  0.028
# 2017-07-11 01:00:00    0  0.026
# 2017-07-11 01:15:00    0  0.018

# %%
df_prod_1.time = pd.to_datetime(df_prod_1.index, format='%Y-%m-%d %H:%M:%S')
df_prod_1.plot()
plt.show()
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
#PanelHouses = productionDF.iloc[1,:].str.contains('4', regex=True)
PanelHouses = productionDF.iloc[1,:] == 9
#print(PanelHouses)

PanelHouses = list(PanelHouses[PanelHouses].index.values)


print(PanelHouses)
# Out:
# ['H03', 'H08', 'H11', 'H15', 'H27']

# %%
# x-axis values 
x = df_prod_1.time 
print(x)
# y-axis values 
y = df_house_1['cons']
print(y)
  
# setting the x - coordinates 
#x = np.arange(0, 2*(np.pi), 0.1) 
# setting the corresponding y - coordinates 
#y = np.sin(x) 
  
# potting the points 
plt.plot(x, y) 
  
# function to show the plot 
plt.show()
# Out:
# DatetimeIndex(['2017-07-11 00:15:00', '2017-07-11 00:30:00',
#                '2017-07-11 00:45:00', '2017-07-11 01:00:00',
#                '2017-07-11 01:15:00', '2017-07-11 01:30:00',
#                '2017-07-11 01:45:00', '2017-07-11 02:00:00',
#                '2017-07-11 02:15:00', '2017-07-11 02:30:00',
#                '2017-07-11 02:45:00', '2017-07-11 03:00:00',
#                '2017-07-11 03:15:00', '2017-07-11 03:30:00',
#                '2017-07-11 03:45:00', '2017-07-11 04:00:00',
#                '2017-07-11 04:15:00', '2017-07-11 04:30:00',
#                '2017-07-11 04:45:00', '2017-07-11 05:00:00',
#                '2017-07-11 05:15:00', '2017-07-11 05:30:00',
#                '2017-07-11 05:45:00', '2017-07-11 06:00:00',
#                '2017-07-11 06:15:00', '2017-07-11 06:30:00',
#                '2017-07-11 06:45:00', '2017-07-11 07:00:00',
#                '2017-07-11 07:15:00', '2017-07-11 07:30:00',
# ...

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))
#fig.suptitle('Consumption by time')
#ax1.plot(x, y)
#ax2.plot(x, -y)

df_prod_month = productionDF.iloc[4:3076,0:2]
df_cons_month = consumptionDF.iloc[4:3076,1:2]

df_house_month = df_prod_month
df_house_month.columns = ['date', 'prod']
df_house_month['cons'] = df_cons_month
df_house_month.set_index('date', inplace=True)

df_prod_month.time = pd.to_datetime(df_prod_month.index, format='%Y-%m-%d %H:%M:%S')
df_prod_month.plot()
plt.show()
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
df_prod_year = productionDF.iloc[4:34180,0:2]
df_cons_year = consumptionDF.iloc[4:34180,1:2]

df_house_year = df_prod_year
df_house_year.columns = ['date', 'prod']
df_house_year['cons'] = df_cons_year
df_house_year.set_index('date', inplace=True)

df_prod_year.time = pd.to_datetime(df_prod_year.index, format='%Y-%m-%d %H:%M:%S')
#plt.ylim(0,200)
#plt.xlim(0,200)
df_prod_year.plot(alpha=0.7)
plt.ylim(0,1.5)
plt.show()
#borrar los máximos para ver mejor en escala los datos
#clean the maximun data to show better the scale
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   if __name__ == '__main__':

# %%
df_prod_full = productionDF.iloc[4:,0:2]
df_cons_full = consumptionDF.iloc[4:,1:2]

df_house_full = df_prod_full
df_house_full.columns = ['date', 'prod']
df_house_full['cons'] = df_cons_full
df_house_full.set_index('date', inplace=True)

df_prod_full.time = pd.to_datetime(df_prod_full.index, format='%Y-%m-%d %H:%M:%S')
df_prod_full.plot()
plt.show()
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   if __name__ == '__main__':

# %%
fig, axs = plt.subplots(2, 2,figsize=(15,15))
axs[0, 0].plot(df_prod_1.time , df_house_1['cons'])
axs[0, 0].set_title('Day')

axs[0, 1].plot(df_prod_month.time, df_prod_month, 'tab:orange')
axs[0, 1].set_title('Month')

axs[1, 0].plot(df_prod_year.time, df_prod_year, 'tab:green')
axs[1, 0].set_title('Year')

axs[1, 1].plot(df_prod_full.time, df_prod_full, 'tab:red')
axs[1, 1].set_title('Full')

for ax in axs.flat:
    ax.set(xlabel='Date', ylabel='Consumption')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# # Visualizations - DWELING

# %%
# %reset
# from __future__ import division

import numpy as np
from sklearn import preprocessing
import math
from matplotlib import pyplot as plt
from matplotlib import patches as patches
import pandas as pd
from numpy import *

# %matplotlib inline
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
filename = 'data.xlsx'
data = pd.read_excel(filename)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 11 columns):
# Unnamed: 0               33 non-null object
# max_prod_date            33 non-null datetime64[ns]
# max_prod                 33 non-null float64
# max_cons_date            33 non-null datetime64[ns]
# max_cons                 33 non-null float64
# max_prod_amperes_date    33 non-null datetime64[ns]
# max_prod_amperes         33 non-null float64
# max_cons_amperes_date    33 non-null datetime64[ns]
# max_cons_amperes         33 non-null float64
# people                   33 non-null int64
# solar_panels             33 non-null int64
# dtypes: datetime64[ns](4), float64(4), int64(2), object(1)
# memory usage: 3.0+ KB

# %%
# max prod

x = data['max_prod_date']
y = data['max_prod']

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 10))

grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=6, alpha=0.5)
main_ax.set_title('\n\nmax prod:')

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='green')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='green')
y_hist.invert_xaxis()





#________________________

# max cons


x = data['max_cons_date']
y = data['max_cons']

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 10))

grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=6, alpha=0.5)
main_ax.set_title('\n\nmax cons:')

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='green')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='green')
y_hist.invert_xaxis()


#__________________________

#relation between solar panels and production


x = data['solar_panels']
y = data['max_prod']

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 10))

grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=6, alpha=0.5)
main_ax.set_title('\n\nrelation between solar panels and production:')


# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='green')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='green')
y_hist.invert_xaxis()


#___________________________

#relation between people and production


x = data['people']
y = data['max_prod']

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 10))

grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=6, alpha=0.5)
main_ax.set_title('\n\nrelation between people and production:')

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='green')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='green')
y_hist.invert_xaxis()


#_________________________________

#relation between people and cons



x = data['people']
y = data['max_cons']

# Set up the axes with gridspec
fig = plt.figure(figsize=(10, 10))

grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=6, alpha=0.5)
main_ax.set_title('\n\nrelation between people and cons:')

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='green')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='green')
y_hist.invert_xaxis()
